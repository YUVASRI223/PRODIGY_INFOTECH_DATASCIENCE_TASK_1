# %% [markdown]
#                                                  TASK -01
#
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable like age or gender distribution in a population.

# %% [markdown]
#  1) import the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2) Download and Load Dataset

# %%
df = pd.read_csv("dataset1.csv", skiprows=4)
df
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                          Africa Eastern and Southern          AFE
# 2                                          Afghanistan          AFG
# 3                           Africa Western and Central          AFW
# 4                                               Angola          AGO
# 5                                              Albania          ALB
# 6                                              Andorra          AND
# 7                                           Arab World          ARB
# 8                                 United Arab Emirates          ARE
# 9                                            Argentina          ARG
# 10                                             Armenia          ARM
# 11                                      American Samoa          ASM
# 12                                 Antigua and Barbuda          ATG
# ...

# %%
3) Clean the Data

# %%
population_df = df[['Country Name', '2022']].dropna()
population_df.columns = ['Country', 'Population']
population_df
# Out:
#                                                Country    Population
# 0                                                Aruba  1.073100e+05
# 1                          Africa Eastern and Southern  7.318214e+08
# 2                                          Afghanistan  4.057884e+07
# 3                           Africa Western and Central  4.973872e+08
# 4                                               Angola  3.563503e+07
# 5                                              Albania  2.777689e+06
# 6                                              Andorra  7.970500e+04
# 7                                           Arab World  4.713521e+08
# 8                                 United Arab Emirates  1.007498e+07
# 9                                            Argentina  4.540790e+07
# 10                                             Armenia  2.969200e+06
# 11                                      American Samoa  4.834200e+04
# 12                                 Antigua and Barbuda  9.284000e+04
# ...

# %% [markdown]
# 4) Bar Chart – Top 10 Countries

# %%
top10 = population_by_country.sort_values(by="Population", ascending=False).head(10)
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=top10, x="Country", y="Population", palette="viridis")
plt.title("Top 10 Most Populous Countries in 2022")
plt.ylabel("Population")
plt.xlabel("Country")
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{int(p.get_height()/1e6):,}M',(p.get_x() + p.get_width() / 2., p.get_height()),ha='center', va='bottom', fontsize=10, color='black')
plt.legend(["Population in Millions"], loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 5) Histogram -  All Countries Population

# %%
plt.figure(figsize=(10, 5))
n, bins, patches = plt.hist(population_by_country["Population"], bins=30, color="skyblue", edgecolor="black")
for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2, patches[i].get_height(), str(int(patches[i].get_height())), ha='center', va='bottom', fontsize=8)
plt.title("Histogram of Population Distribution (2022)")
plt.xlabel("Population")
plt.ylabel("Number of Countries")
plt.legend(["Frequency of Countries"], loc='upper right')
plt.tight_layout()
plt.show()
